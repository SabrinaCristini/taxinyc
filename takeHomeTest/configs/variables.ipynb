# %% [markdown]
# # SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
            .appName("ifood_processo_seletivo") \
            .master('local[*]') \
            .config("spark.driver.maxResultSize", "50g") \
            .getOrCreate()

# %% [markdown]
# # Datalake Informations

# %%
acess_key_minio="MgxwxlLvtLkLwhU5V54f"
secret_key_minio="bZe7ArCNCAAhcPwn0AEq2sjaX9E1koDeAv8cHEK7"
endpoint_minio="http://127.0.0.1:9001"

# %% [markdown]
# # Variables task1 and task2

# %%
database_name = "nyc" #Database Name
table_name = "yellow_taxi" #Table Name

#Variables on task 1
raw_files = "/home/dna/dev/ifoodps/taxinyc/files/raw/yellow_taxi_files/" # Files to read
raw_file_format = "parquet" # File format to read
bronze_files = "/home/dna/dev/ifoodps/taxinyc/files/bronze/yellow_taxi_files/" #path to save parquet files transformed
bronze_file_format = "parquet" #file format of the transformed files
